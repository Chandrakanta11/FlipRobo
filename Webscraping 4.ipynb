# %% [markdown]
# # 1. Scrape the details of most viewed videos on YouTube from Wikipedia.Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videosYou need to find following details:A) RankB) NameC) ArtistD) Upload dateE) Views

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
driver = webdriver.Chrome(r"C:\Users\User\Downloads\Fliprobo\chromedriver.exe")
driver.get("https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos")
driver.maximize_window()

# %%
Rank=[]
Name=[]
Artist=[]
Date=[]
Views=[]

# %%
try:
    ranks=driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[1]")
    for i in ranks:
        Rank.append(i.text)
except NoSuchElementException: # handling no such element exception
    Rank.append('-')
time.sleep(1)

try:
    name=driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[2]")
    for i in name:
        Name.append(i.text)
except NoSuchElementException: # handling no such element exception
    Name.append('-')
time.sleep(1)

try:
    artist=driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[3]")
    for i in artist:
        Artist.append(i.text)
except NoSuchElementException: # handling no such element exception
    Arist.append('-')
time.sleep(1)

try:
    views=driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[4]")
    for i in views:
        Views.append(i.text)
except NoSuchElementException: # handling no such element exception
    Views.append('-')
time.sleep(1)

try:
    date=driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[5]")
    for i in date:
        Date.append(i.text)
except NoSuchElementException: # handling no such element exception
    Date.append('-')
time.sleep(1)

# %%
df1= pd.DataFrame({'Rank':Rank,'Name':Name,'Artist':Artist,'Views':Views,'Date':Date})
df1
# Out:
#    Rank                                             Name  \
# 0    1.                            "Baby Shark Dance"[4]
# 1    2.                                   "Despacito"[7]
# 2    3.                       "Johny Johny Yes Papa"[14]
# 3    4.                                  "Bath Song"[15]
# 4    5.                               "Shape of You"[16]
# 5    6.                              "See You Again"[18]
# 6    7.                "Phonics Song with Two Words"[23]
# 7    8.                                "Uptown Funk"[24]
# 8    9.                          "Wheels on the Bus"[25]
# 9   10.  "Learning Colors – Colorful Eggs on a Farm"[26]
# 10  11.                              "Gangnam Style"[27]
# 11  12.   "Masha and the Bear – Recipe for Disaster"[32]
# 12  13.                             "Dame Tu Cosita"[33]
# 13  14.                                      "Sugar"[34]
# 14  15.                                       "Roar"[35]
# ...

# %% [markdown]
# # 2. Scrape the details team India’s international fixtures from bcci.tv.Url = https://www.bcci.tv/.You need to find following details:A) Match title (I.e. 1st ODI)B) SeriesC) PlaceD) DateE) TimeNote: - From bcci.tv home page you have reach to the international fixture page through code.

# %%
driver = webdriver.Chrome(r"C:\Users\User\Downloads\Fliprobo\chromedriver.exe")
driver.get("https://www.bcci.tv/")
driver.maximize_window()

# %%
item = driver.find_element(By.XPATH,'//li[@class="nav-item"]')
item.click()

# %%
Title=[]
Series=[]
Place=[]
Date=[]
Time=[]

# Scraping title
title=driver.find_elements(By.XPATH,"//span[@class='matchOrderText ng-binding ng-scope']")
for i in title:
    Title.append(i.text.split("-")[0])

# Scraping series
series=driver.find_elements(By.XPATH,"//span[@class='ng-binding']")
for i in series:
    Series.append(i.text)

# Scraping place
place=driver.find_elements(By.XPATH,"//div[@class='fix-place ng-binding ng-scope']")
for i in place:
    Place.append(i.text.split("-")[1])

# Scraping date
date=driver.find_elements(By.XPATH,"//h5[@class='ng-binding']")
for i in date:
    Date.append(i.text)

# Scraping time
time=driver.find_elements(By.XPATH,"//h5[@class='text-right ng-binding']")
for i in time:
    Time.append(i.text)  
    
df2=pd.DataFrame({'Title':Title,'Series':Series,'Place':Place,'Date':Date,'Time':Time})
df2
# Out:
#        Title                                          Series  \
# 0  4th T20I   INDIA WOMEN U19 TOUR OF SOUTH AFRICA WOMEN U19
# 1  1st T20I       SRI LANKA TOUR OF INDIA T20 SERIES 2022-23
# 2  5th T20I   INDIA WOMEN U19 TOUR OF SOUTH AFRICA WOMEN U19
# 3  2nd T20I       SRI LANKA TOUR OF INDIA T20 SERIES 2022-23
# 4  3rd T20I       SRI LANKA TOUR OF INDIA T20 SERIES 2022-23
# 5   1st ODI       SRI LANKA TOUR OF INDIA ODI SERIES 2022-23
# 6   2nd ODI       SRI LANKA TOUR OF INDIA ODI SERIES 2022-23
# 7   3rd ODI       SRI LANKA TOUR OF INDIA ODI SERIES 2022-23
#
#                                                Place         Date         Time
# 0                 Steyn City School Ground, Pretoria   2 JAN 2023  5:15 PM IST
# 1                           Wankhede Stadium, Mumbai   3 JAN 2023  7:00 PM IST
# 2                 Steyn City School Ground, Pretoria   4 JAN 2023  1:30 PM IST
# 3      Maharashtra Cricket Association Stadium, Pune   5 JAN 2023  7:00 PM IST
# ...

# %% [markdown]
# # 3. Scrape the details of selenium exception from guru99.com.Url = https://www.guru99.com/You need to find following details:A) NameB) DescriptionNote: - From guru99 home page you have to reach to selenium exception handling page through code.

# %%
driver = webdriver.Chrome(r"C:\Users\User\Downloads\Fliprobo\chromedriver.exe")
driver.get("https://www.guru99.com/")
driver.maximize_window()

# %%
search_button=driver.find_element(By.XPATH,"/html/body/footer/div/div[1]/div/div/div/div/div/div/section/div/div/div[2]/div/div/div/div/div[2]/div/div/div[2]/div/div[2]/div/div/div[3]/div/div/div[2]/div/div/a/div[1]/div/div/div/span")
search_button.click()
button=driver.find_element(By.XPATH,"/html/body/div[1]/div/div/div/main/div/article/div/div/table[5]/tbody/tr[34]/td[1]/a")
button.click()

# %%
name =[]
description=[]

# %%
all_info=[]
try:
    all_tags =driver.find_elements(By.XPATH,'//div[@class="entry-content single-content"]/p')
    for i in all_tags:
        all_info.append(i.text.split(":"))
except NoSuchElementException:
    all_info.append('--')
all_info1= all_info[:41]

jj=[]
for i in all_info1:
    for j in i:
        jj.append(j)
        

for i in range(0, len(jj)):
    if i % 2 ==0:
        name.append(jj[i])

for i in range(0, len(jj)):
    if i % 2 ==1:
        description.append(jj[i])

# %%
data_list= list(zip(name,description ))

df3= pd.DataFrame(data_list, 
    columns =['Name','Description'],
    index=pd.RangeIndex(start=1, stop=42, name='Sr. No.'))

#Print the required data

print ("Details of selenium exception from guru99.com:\n")
df3
# Out:
# Details of selenium exception from guru99.com:
#                                             Name  \
# Sr. No.
# 1                  1. ElementNotVisibleException
# 2               2. ElementNotSelectableException
# 3                      3. NoSuchElementException
# 4                        4. NoSuchFrameException
# 5                     5. NoAlertPresentException
# 6                       6. NoSuchWindowException
# 7              7. StaleElementReferenceException
# 8                    8. SessionNotFoundException
# 9                            9. TimeoutException
# 10                        10. WebDriverException
# 11                 11. ConnectionClosedException
# 12          12. ElementClickInterceptedException
# 13           13. ElementNotInteractableException
# 14                  14. ErrorInResponseException
# 15       15. ErrorHandler.UnknownServerException
# 16              16. ImeActivationFailedException
# 17                  17. ImeNotAvailableException
# ...

# %% [markdown]
# # 4. Scrape the details of State-wise GDP of India from statisticstime.com.Url = http://statisticstimes.com/You have to find following details:A) RankB) StateC) GSDP(18-19)- at current pricesD) GSDP(19-20)- at current pricesE) Share(18-19)F) GDP($ billion)Note: - From statisticstimes home page you have to reach to economy page through code.

# %%
driver = webdriver.Chrome(r"C:\Users\User\Downloads\Fliprobo\chromedriver.exe")
driver.get("http://statisticstimes.com/")
driver.maximize_window()

# %%
search_button=driver.find_element(By.XPATH,"/html/body/div[2]/div[1]/div[2]/div[2]/button")
search_button.click()
search_button=driver.find_element(By.XPATH,"/html/body/div[2]/div[1]/div[2]/div[2]/div/a[3]")
search_button.click()

# %%
state_button=driver.find_element(By.XPATH,"/html/body/div[2]/div[2]/div[2]/ul/li[1]/a")
state_button.click()

# %%
rank=[]
state=[]
gsdp_18=[]
gsdp_19=[]
share=[]
gdp=[]

# %%
#Scraping Rank
a=driver.find_elements(By.XPATH,"//td[@class='data1']")
for i in a[:33]:
    rank.append(i.text)

#Scraping State    
b=driver.find_elements(By.XPATH,"//td[@class='name']")
for i in b[:33]:
    state.append(i.text)

#Scraping gsdp_18    
c=driver.find_elements(By.XPATH,"//td[@class='data sorting_1']")
for i in c[:33]:
    gsdp_18.append(i.text)

#Scraping gsdp_19 
j=0
c=driver.find_elements(By.XPATH,"//td[@class='data']")
for i in range(33):
    gsdp_19.append(c[j].text)
    j=j+5


#Scraping share
j=1
for i in range(33):
    share.append(c[j].text)
    j=j+5
      
#Scraping gdp
j=2
for i in range(33):
    gdp.append(c[j].text)
    j=j+5

# %%
df4=pd.DataFrame(list(zip(rank,state,gsdp_18,gsdp_19,share,gdp)),
                          columns=['Rank','State','gsdp_18','gsdp_19','share','GDP'])
df4
# Out:
#    Rank                      State    gsdp_18    gsdp_19   share      GDP
# 0     1                Maharashtra  2,632,792          -  13.94%  399.921
# 1     2                 Tamil Nadu  1,630,208  1,845,853   8.63%  247.629
# 2     3              Uttar Pradesh  1,584,764  1,687,818   8.39%  240.726
# 3     4                    Gujarat  1,502,899          -   7.96%  228.290
# 4     5                  Karnataka  1,493,127  1,631,977   7.91%  226.806
# ..  ...                        ...        ...        ...     ...      ...
# 94   27                    Manipur     27,870     31,790   0.15%    4.233
# 95   28                   Nagaland     27,283          -   0.14%    4.144
# 96   29          Arunachal Pradesh     24,603          -   0.13%    3.737
# 97   30                    Mizoram     22,287     26,503   0.12%    3.385
# 98   31  Andaman & Nicobar Islands          -          -       -        -
#
# [99 rows x 6 columns]

# %% [markdown]
# # 5. Scrape the details of trending repositories on Github.comUrl = https://github.com/You have to find the following details:A) Repository titleB) Repository descriptionC) Contributors countD) Language usedNote: - From the home page you have to click on the trending option from Explore menu through code.

# %%
driver = webdriver.Chrome(r"C:\Users\User\Downloads\Fliprobo\chromedriver.exe")
driver.get("https://github.com/")
driver.maximize_window()

# %%
explore=driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/button")
explore.click()
trending=driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/div/ul[3]/li[3]/a")
trending.click()

# %%
title=[]
desc=[]
count=[]
language=[]

# %%
#Scraping repository title
a=driver.find_elements(By.XPATH,"//h1[@class='h3 lh-condensed']")
for i in a:
    title.append(i.text)

#Scraping repository description
d=driver.find_elements(By.XPATH,"//p[@class='col-9 color-fg-muted my-1 pr-4']")
for i in d:
    desc.append(i.text)
    
#Scraping count
d=driver.find_elements(By.XPATH,"//a[@class='Link--muted d-inline-block mr-3']")
for i in range(len(d)):
    if i%2==0:
        count.append(d[i].text)

#Scraping language
l=driver.find_elements(By.XPATH,"//span[@class='d-inline-block ml-0 mr-3']")
for i in l:        
    language.append(i.text)
    
print("Repository title:\n",title)
print("\n")
print("Repository Description:\n",desc)
print("\n")
print("Count:\n",count)
print("\n")
print("Language used:\n",language)

df5=pd.DataFrame(list(zip(title,desc,count,language)),
                          columns=['Title','Desc','Count','Language'])
df5
# Out:
# Repository title:
# ...

# %% [markdown]
# # 6. Scrape the details of top 100 songs on billiboard.com.Url = https:/www.billboard.com/You have to find the following details:A) Song nameB) Artist nameC) Last week rankD) Peak rankE) Weeks on boardNote: - From the home page you have to click on the charts option then hot 100-page link through code

# %%
driver = webdriver.Chrome(r"C:\Users\User\Downloads\Fliprobo\chromedriver.exe")
driver.get("http://www.billboard.com/")
driver.maximize_window()

# %%
search_button=driver.find_element(By.XPATH,"/html/body/div[3]/header/div/div[2]/div/div/div[2]/div[2]/div/div/nav/ul/li[1]/a")
search_button.click()
search_button=driver.find_element(By.XPATH,"/html/body/div[3]/main/div[2]/div[1]/div[1]/div/div/div[1]/div/div[2]/span/a")
search_button.click()

# %%
name=[]
artist=[]
lwr=[]
pr=[]
weeks=[]

# %%
a=driver.find_elements(By.XPATH,"//ul[@class='lrv-a-unstyle-list lrv-u-flex lrv-u-height-100p lrv-u-flex-direction-column@mobile-max']")

artist.append(a[0].text.split("\n")[1])
lwr.append(a[0].text.split("\n")[2])
pr.append(a[0].text.split("\n")[3])
weeks.append(a[0].text.split("\n")[4])

#Scraping name
a=driver.find_elements(By.TAG_NAME,"h3")
for i in a[1:]:
    name.append(i.text)
while ("" in name):
    name.remove("")    
 

 #Scraping artist
a=driver.find_elements(By.XPATH,"//span[@class='c-label  a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only']")
for i in a:
    artist.append(i.text)
 

 #Scraping last_week_rank
j=0
a=driver.find_elements(By.XPATH,"//span[@class='c-label  a-font-primary-m lrv-u-padding-tb-050@mobile-max']")
for i in range(len(a)):
    lwr.append(a[j].text)
    j=j+3
    if (len(a)-1)<=j:
        break


#Scraping peak_rank
j=1
a=driver.find_elements(By.XPATH,"//span[@class='c-label  a-font-primary-m lrv-u-padding-tb-050@mobile-max']")
for i in range(len(a)):
    pr.append(a[j].text)
    j=j+3
    if (len(a)-1)<=j:
        break


#Scraping weeks
j=2
a=driver.find_elements(By.XPATH,"//span[@class='c-label  a-font-primary-m lrv-u-padding-tb-050@mobile-max']")
for i in range(len(a)):
    weeks.append(a[j].text)
    j=j+3
    if (len(a)-1)<=j:
        break
while "" in lwr: 
    lwr.remove("")
while "" in pr: 
    pr.remove("")
while "" in weeks: 
    weeks.remove("")
    
df6=pd.DataFrame(list(zip(name[:100],artist,lwr,pr,weeks)),
                          columns=['Song Name','Artist','Last Week Rank','Peak rank','Weeks on board'])
df6
# Out:
#                             Song Name                       Artist  \
# 0     All I Want For Christmas Is You                 Mariah Carey
# 1   Rockin' Around The Christmas Tree                   Brenda Lee
# 2                    Jingle Bell Rock                  Bobby Helms
# 3             A Holly Jolly Christmas                    Burl Ives
# 4                      Last Christmas                        Wham!
# ..                                ...                          ...
# 95                          Down Home                 Jimmie Allen
# 96                One Thing At A Time                Morgan Wallen
# 97                     Hold Me Closer  Elton John & Britney Spears
# 98                                Far                          SZA
# 99                           All Mine                 Brent Faiyaz
#
#    Last Week Rank Peak rank Weeks on board
# 0               1         1             57
# 1               2         2             51
# ...

# %% [markdown]
# # 7. Scrape the details of Data science recruiters from naukri.com.Url = https://www.naukri.com/You have to find the following details:A) NameB) DesignationC) CompanyD) Skills they hire forE) LocationNote: - From naukri.com homepage click on the recruiters option and the on the search pane type Data science andclick on search. All this should be done through code

# %%
driver = webdriver.Chrome(r"C:\Users\User\Downloads\Fliprobo\chromedriver.exe")
driver.get("https://www.naukri.com/hr-recruiters-consultants")
driver.maximize_window()

# %%
search_job=driver.find_element(By.XPATH,"/html/body/div[2]/div[2]/div[1]/div[1]/form/div[1]/div/div[1]/div[1]/div[2]/input")
search_job.send_keys("Data Scientist")
search_button=driver.find_element(By.XPATH,"/html/body/div[2]/div[2]/div[1]/div[1]/form/div[1]/button")
search_button.click()

# %%
name=[]
desg=[]
company=[]
skills=[]
location=[]

# %%
#Scraping Name
a=driver.find_elements(By.XPATH,"//span[@class='fl ellipsis']")
for i in a:
    name.append(i.text)

#Scraping Designation
a=driver.find_elements(By.XPATH,"//span[@class='ellipsis clr']")
for i in a:
    desg.append(i.text)

#Scrapping Company
a=driver.find_elements(By.XPATH,"//a[@class='ellipsis']")
for i in range(1,len(a),2):
    company.append(a[i].text)

#Scraping skills
a=driver.find_elements(By.XPATH,"//div[@class='hireSec highlightable']")
for i in a:
    skills.append(i.text)

#Scraping location
a=driver.find_elements(By.XPATH,"//small[@class='ellipsis']")
for i in a:
    location.append(i.text)

# %%
df7=pd.DataFrame(list(zip(name,desg,company,skills,location)),
                          columns=['Name','Designation','Company','Skills','Location'])
df7
# Out:
#                                             Name  \
# 0                                      Tanushree
# 1                                  sashi bhushan
# 2                                         Bitapi
# 3                                 Gajendra Singh
# 4                              Sadashiv Kulkarni
# 5                                    Invelopment
# 6                              Anjali Srivastava
# 7                                     Helly Vyas
# 8                                   Ashish Verma
# 9                                  Shiva Kumar N
# 10                              Bhuwneshari Devi
# 11                            Balaji Prabhakaran
# 12                                    HS Sandesh
# 13                               Anoop Somarajan
# 14                                   Datafoundry
# 15                               A Valsa Florina
# 16                                 Kalaivani M V
# 17                                    Prashant K
# ...

# %% [markdown]
# # 8. Scrape the details of Highest selling novels.Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-greycompare/You have to find the following details:A) Book nameB) Author nameC) Volumes soldD) PublisherE) Genre

# %%
driver = webdriver.Chrome(r"C:\Users\User\Downloads\Fliprobo\chromedriver.exe")
driver.get("https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare")
driver.maximize_window()

# %%
name=[]
aut=[]
vol=[]
pub=[]
gen=[]

# %%
a=driver.find_elements(By.XPATH,"//td[@class='left']")
for i in range(1,len(a),5):
    name.append(a[i].text)
for i in range(2,len(a),5):
    aut.append(a[i].text)
for i in range(3,len(a),5):
    vol.append(a[i].text)
for i in range(4,len(a),5):
    pub.append(a[i].text)
a=driver.find_elements(By.XPATH,"//td[@class='last left']")
for i in a:
    gen.append(i.text)

# %%
df8=pd.DataFrame(list(zip(name,aut,vol,pub,gen)),
                          columns=['Book Name','Author','Volumes Sold','Publisher','Genre'])
df8
# Out:
#                                             Book Name            Author  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volumes Sold        Publisher                        Genre
# ...

# %% [markdown]
# # 9. Scrape the details most watched tv series of all time from imdb.com.Url = https://www.imdb.com/list/ls095964455/You have to find the following details:A) NameB) Year spanC) GenreD) Run timeE) RatingsF) Votes

# %%
driver = webdriver.Chrome(r"C:\Users\User\Downloads\Fliprobo\chromedriver.exe")
driver.get("https://www.imdb.com/list/ls095964455/")
driver.maximize_window()

# %%
name=[]
year=[]
gen=[]
time=[]
ratings=[]
votes=[]

# %%
a=driver.find_elements(By.XPATH,"//h3[@class='lister-item-header']")
for i in a:
    name.append(i.text.split(".")[1].split("(")[0])
    
#Scraping year of span
a=driver.find_elements(By.XPATH,"//span[@class='lister-item-year text-muted unbold']")
for i in a:
    year.append(i.text.split("(")[1].split(")")[0])

#Scraping genre
a=driver.find_elements(By.XPATH,"//span[@class='genre']")
for i in a:
    gen.append(i.text)

#Scraping run time
a=driver.find_elements(By.XPATH,"//span[@class='runtime']")
for i in a:
    time.append(i.text)

#Scraping rating
a=driver.find_elements(By.XPATH,"//span[@class='ipl-rating-star__rating']")
for i in a:
    if i.text=="\n" or i.text=="Rate" or i.text=="":
        continue
    ratings.append(i.text)  
    
##Scraping votes
a=driver.find_elements(By.XPATH,"//p[@class='text-muted text-small']")

for i in range(2,len(a),3):
    votes.append(a[i].text.split(":")[1])

# %%
df9=pd.DataFrame(list(zip(name,year,gen,time,ratings,votes)),
                          columns=['Show Name','Year of Span','Genre','Run Time','Rating','Votes'])
df9
# Out:
#                            Show Name Year of Span                     Genre  \
# 0                   Game of Thrones     2011–2019  Action, Adventure, Drama
# 1                   Stranger Things        2016–     Drama, Fantasy, Horror
# 2                  The Walking Dead     2010–2022   Drama, Horror, Thriller
# 3                    13 Reasons Why     2017–2020  Drama, Mystery, Thriller
# 4                           The 100     2014–2020    Drama, Mystery, Sci-Fi
# ..                               ...          ...                       ...
# 95                            Reign     2013–2017                     Drama
# 96   A Series of Unfortunate Events     2017–2019  Adventure, Comedy, Drama
# 97                   Criminal Minds        2005–      Crime, Drama, Mystery
# 98            Scream: The TV Series     2015–2019      Comedy, Crime, Drama
# 99       The Haunting of Hill House          2018    Drama, Horror, Mystery
#
#    Run Time Rating       Votes
# ...

# %% [markdown]
# # 10. Details of Datasets from UCI machine learning repositories.Url = https://archive.ics.uci.edu/You have to find the following details:A) Dataset nameB) Data typeC) TaskD) Attribute typeE) No of instancesF) No of attributeG) YearNote: - from the home page you have to go to the ShowAllDataset page through code

# %%
driver = webdriver.Chrome(r"C:\Users\User\Downloads\Fliprobo\chromedriver.exe")

driver.get('https://archive.ics.uci.edu/')

#Clicking on view all datasets link
datasets=driver.find_element(By.XPATH,"/html/body/table[1]/tbody/tr/td[2]/span[2]/a/font/b")
try:
    datasets.click()
except ElementNotInteractableException:
    driver.get(datasets.get_attribute('href'))

#Creating empty lists for storing the data
Name=[]
Type=[]
Task=[]
Attribute=[]
No_of_Instance=[]
No_of_Attribute=[]
Year=[]

# %%
try:
    names=driver.find_elements(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[1]/table/tbody/tr/td[2]/p/b/a")
    for i in names:
        Name.append(i.text)
except NoSuchElementException:
    Name.append('-')
    
#Scrapping the data having data type
try:
    types=driver.find_elements(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[2]")
    for i in types[1:]:
        Type.append(i.text)
except NoSuchElementException:
    Type.append('-')
    
#Scrapping the data having default task
try:
    task=driver.find_elements(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[3]")
    for i in task[1:]:
        Task.append(i.text)
except NoSuchElementException:
    Task.append('-')
        
#Scrapping the data having attribute types
try:
    attribute=driver.find_elements(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[4]")
    for i in attribute[1:]:
        Attribute.append(i.text)
except NoSuchElementException:
     Attribute.append('-')
        
#Scrapping the data having no of instances
try:
    instance=driver.find_elements(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[5]")
    for i in instance[1:]:
        No_of_Instance.append(i.text)
except NoSuchElementException:
    No_of_Instance.append('-')
        
#Scrapping the data having no of attributes
try:
    attribute_no=driver.find_elements(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[6]")
    for i in attribute_no[1:]:
        No_of_Attribute.append(i.text)
except NoSuchElementException:
    No_of_Attribute.append('-')
        
#Scrapping the data having the year details
try:
    year=driver.find_elements(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[7]")
    for i in year[1:]:
        Year.append(i.text)
except NoSuchElementException:
    Year.append('-')
    

#Creating the dataframe
df10=pd.DataFrame({"Name":Name,"Data types":Type,"Default Task":Task,"Attribute types":Attribute, 
                 "No of instances":No_of_Instance,"No of atrributes":No_of_Attribute,"Year":Year})
df10
# Out:
#                                                   Name  \
# 0                                              Abalone
# 1                                                Adult
# 2                                            Annealing
# 3                         Anonymous Microsoft Web Data
# 4                                           Arrhythmia
# ..                                                 ...
# 617  Influenza outbreak event prediction via Twitte...
# 618                      Turkish Music Emotion Dataset
# 619                      Maternal Health Risk Data Set
# 620                          Room Occupancy Estimation
# 621  Image Recognition Task Execution Times in Mobi...
#
#                      Data types          Default Task  \
# 0                 Multivariate        Classification
# 1                 Multivariate        Classification
# 2                 Multivariate        Classification
# 3                                Recommender-Systems
# ...
